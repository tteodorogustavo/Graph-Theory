# %% [markdown]
# ## Grafos relativos aos primeiros arquivo de busca em largura
#
# #### Arquivos nomeados como "BHW*.dat"

# %% [markdown]
# 1 - BHW1.bat

# %%
from grafo import ler_arquivo, desenhar_grafo, estatisticas_grafo

grafo = ler_arquivo("selected_instances/BHW1.dat")

estatisticas = estatisticas_grafo(grafo)

print("Estatísticas do grafo:")
for chave, valor in estatisticas.items():
    print(f"{chave}: {valor}")

desenhar_grafo(grafo)
# Out:
# Estatísticas do grafo:
# Qtd Vértices: 12
# Qtd Arestas: 11
# Qtd Arcos: 22
# Qtd Vértices Requeridos: 12
# Qtd Arestas Requeridas: 11
# Qtd Arcos Requeridos: 11
# Densidade: 0.25
# Grau Mínimo: 6
# Grau Máximo: 10
# Intermediação: {1: 18, 2: 22, 3: 6, 4: 0, 5: 14, 6: 38, 7: 22, 8: 16, 9: 14, 10: 6, 11: 0, 12: 22}
# Caminho Médio: 16.712
# Diâmetro: 30

# %% [markdown]
# 2. BHW2.bat

# %%
from grafo import ler_arquivo, desenhar_grafo, estatisticas_grafo

grafo = ler_arquivo("selected_instances/BHW2.dat")

estatisticas = estatisticas_grafo(grafo)

print("Estatísticas do grafo:")
for chave, valor in estatisticas.items():
    print(f"{chave}: {valor}")

desenhar_grafo(grafo)
# Out:
# Estatísticas do grafo:
# Qtd Vértices: 12
# Qtd Arestas: 0
# Qtd Arcos: 25
# Qtd Vértices Requeridos: 12
# Qtd Arestas Requeridas: 0
# Qtd Arcos Requeridos: 25
# Densidade: 0.1893939393939394
# Grau Mínimo: 3
# Grau Máximo: 6
# Intermediação: {1: 40, 2: 23, 3: 18, 4: 6, 5: 38, 6: 38, 7: 3, 8: 3, 9: 12, 10: 29, 11: 15, 12: 46}
# Caminho Médio: 29.568
# Diâmetro: 72

# %% [markdown]
# 3. BHW3.bat

# %%
from grafo import ler_arquivo, desenhar_grafo, estatisticas_grafo

grafo = ler_arquivo("selected_instances/BHW3.dat")

estatisticas = estatisticas_grafo(grafo)

print("Estatísticas do grafo:")
for chave, valor in estatisticas.items():
    print(f"{chave}: {valor}")

desenhar_grafo(grafo)
# Out:
# Estatísticas do grafo:
# Qtd Vértices: 13
# Qtd Arestas: 8
# Qtd Arcos: 30
# Qtd Vértices Requeridos: 12
# Qtd Arestas Requeridas: 8
# Qtd Arcos Requeridos: 7
# Densidade: 0.24358974358974358
# Grau Mínimo: 4
# Grau Máximo: 10
# Intermediação: {1: 30, 2: 46, 3: 0, 4: 0, 5: 10, 6: 34, 7: 0, 8: 8, 9: 6, 10: 24, 11: 10, 12: 10, 13: 12}
# Caminho Médio: 24.923
# Diâmetro: 47

# %% [markdown]
# 4. BHW4.bat

# %%
from grafo import ler_arquivo, desenhar_grafo, estatisticas_grafo

grafo = ler_arquivo("selected_instances/BHW4.dat")

estatisticas = estatisticas_grafo(grafo)

print("Estatísticas do grafo:")
for chave, valor in estatisticas.items():
    print(f"{chave}: {valor}")

desenhar_grafo(grafo)
# Out:
# Estatísticas do grafo:
# Qtd Vértices: 11
# Qtd Arestas: 0
# Qtd Arcos: 44
# Qtd Vértices Requeridos: 11
# Qtd Arestas Requeridas: 0
# Qtd Arcos Requeridos: 44
# Densidade: 0.4
# Grau Mínimo: 6
# Grau Máximo: 10
# Intermediação: {1: 62, 2: 10, 3: 19, 4: 20, 5: 4, 6: 0, 7: 20, 8: 21, 9: 1, 10: 0, 11: 1}
# Caminho Médio: 3.655
# Diâmetro: 10

# %% [markdown]
# 5. BHW5.bat

# %%
from grafo import ler_arquivo, desenhar_grafo, estatisticas_grafo

grafo = ler_arquivo("selected_instances/BHW5.dat")

estatisticas = estatisticas_grafo(grafo)

print("Estatísticas do grafo:")
for chave, valor in estatisticas.items():
    print(f"{chave}: {valor}")

desenhar_grafo(grafo)
# Out:
# Estatísticas do grafo:
# Qtd Vértices: 40
# Qtd Arestas: 0
# Qtd Arcos: 132
# Qtd Vértices Requeridos: 40
# Qtd Arestas Requeridas: 0
# Qtd Arcos Requeridos: 132
# Densidade: 0.08461538461538462
# Grau Mínimo: 4
# Grau Máximo: 16
# Intermediação: {1: 746, 2: 354, 3: 338, 4: 216, 5: 122, 6: 400, 7: 428, 8: 134, 9: 10, 10: 0, 11: 132, 12: 156, 13: 374, 14: 0, 15: 12, 16: 72, 17: 174, 18: 210, 19: 0, 20: 124, 21: 28, 22: 166, 23: 0, 24: 8, 25: 66, 26: 0, 27: 62, 28: 0, 29: 38, 30: 32, 31: 16, 32: 8, 33: 260, 34: 132, 35: 12, 36: 184, 37: 160, 38: 22, 39: 64, 40: 0}
# Caminho Médio: 14.113
# Diâmetro: 32

# %% [markdown]
# 6. BHW6.bat

# %%
from grafo import ler_arquivo, desenhar_grafo, estatisticas_grafo

grafo = ler_arquivo("selected_instances/BHW6.dat")

estatisticas = estatisticas_grafo(grafo)

print("Estatísticas do grafo:")
for chave, valor in estatisticas.items():
    print(f"{chave}: {valor}")

desenhar_grafo(grafo)
# Out:
# Estatísticas do grafo:
# Qtd Vértices: 40
# Qtd Arestas: 37
# Qtd Arcos: 58
# Qtd Vértices Requeridos: 40
# Qtd Arestas Requeridas: 37
# Qtd Arcos Requeridos: 58
# Densidade: 0.060897435897435896
# Grau Mínimo: 4
# Grau Máximo: 16
# Intermediação: {1: 746, 2: 354, 3: 338, 4: 216, 5: 122, 6: 400, 7: 428, 8: 134, 9: 10, 10: 0, 11: 132, 12: 156, 13: 374, 14: 0, 15: 12, 16: 72, 17: 174, 18: 210, 19: 0, 20: 124, 21: 28, 22: 166, 23: 0, 24: 8, 25: 66, 26: 0, 27: 62, 28: 0, 29: 38, 30: 32, 31: 16, 32: 8, 33: 260, 34: 132, 35: 12, 36: 184, 37: 160, 38: 22, 39: 64, 40: 0}
# Caminho Médio: 14.113
# Diâmetro: 32

# %% [markdown]
# 7. BHW7.bat

# %%
from grafo import ler_arquivo, desenhar_grafo, estatisticas_grafo

grafo = ler_arquivo("selected_instances/BHW7.dat")

estatisticas = estatisticas_grafo(grafo)

print("Estatísticas do grafo:")
for chave, valor in estatisticas.items():
    print(f"{chave}: {valor}")

desenhar_grafo(grafo)
# Out:
# Estatísticas do grafo:
# Qtd Vértices: 50
# Qtd Arestas: 0
# Qtd Arcos: 194
# Qtd Vértices Requeridos: 50
# Qtd Arestas Requeridas: 0
# Qtd Arcos Requeridos: 194
# Densidade: 0.07918367346938776
# Grau Mínimo: 4
# Grau Máximo: 10
# Intermediação: {1: 0, 2: 12, 3: 88, 4: 4, 5: 0, 6: 94, 7: 104, 8: 84, 9: 246, 10: 8, 11: 562, 12: 568, 13: 648, 14: 656, 15: 796, 16: 144, 17: 8, 18: 0, 19: 566, 20: 10, 21: 50, 22: 0, 23: 456, 24: 50, 25: 38, 26: 606, 27: 44, 28: 70, 29: 54, 30: 544, 31: 410, 32: 182, 33: 40, 34: 620, 35: 346, 36: 468, 37: 584, 38: 0, 39: 0, 40: 298, 41: 172, 42: 176, 43: 228, 44: 78, 45: 56, 46: 0, 47: 92, 48: 20, 49: 0, 50: 0}
# Caminho Médio: 11.1
# Diâmetro: 31

# %% [markdown]
# 8. BHW8.bat

# %%
from grafo import ler_arquivo, desenhar_grafo, estatisticas_grafo

grafo = ler_arquivo("selected_instances/BHW8.dat")

estatisticas = estatisticas_grafo(grafo)

print("Estatísticas do grafo:")
for chave, valor in estatisticas.items():
    print(f"{chave}: {valor}")

desenhar_grafo(grafo)
# Out:
# Estatísticas do grafo:
# Qtd Vértices: 50
# Qtd Arestas: 0
# Qtd Arcos: 194
# Qtd Vértices Requeridos: 50
# Qtd Arestas Requeridas: 0
# Qtd Arcos Requeridos: 97
# Densidade: 0.07918367346938776
# Grau Mínimo: 4
# Grau Máximo: 10
# Intermediação: {1: 0, 2: 12, 3: 88, 4: 4, 5: 0, 6: 94, 7: 104, 8: 84, 9: 246, 10: 8, 11: 562, 12: 568, 13: 648, 14: 656, 15: 796, 16: 144, 17: 8, 18: 0, 19: 566, 20: 10, 21: 50, 22: 0, 23: 456, 24: 50, 25: 38, 26: 606, 27: 44, 28: 70, 29: 54, 30: 544, 31: 410, 32: 182, 33: 40, 34: 620, 35: 346, 36: 468, 37: 584, 38: 0, 39: 0, 40: 298, 41: 172, 42: 176, 43: 228, 44: 78, 45: 56, 46: 0, 47: 92, 48: 20, 49: 0, 50: 0}
# Caminho Médio: 11.1
# Diâmetro: 31

# %% [markdown]
# 9. BHW9.bat

# %%
from grafo import ler_arquivo, desenhar_grafo, estatisticas_grafo

grafo = ler_arquivo("selected_instances/BHW9.dat")

estatisticas = estatisticas_grafo(grafo)

print("Estatísticas do grafo:")
for chave, valor in estatisticas.items():
    print(f"{chave}: {valor}")

desenhar_grafo(grafo)
# Out:
# Estatísticas do grafo:
# Qtd Vértices: 50
# Qtd Arestas: 26
# Qtd Arcos: 142
# Qtd Vértices Requeridos: 50
# Qtd Arestas Requeridas: 26
# Qtd Arcos Requeridos: 142
# Densidade: 0.06857142857142857
# Grau Mínimo: 4
# Grau Máximo: 10
# Intermediação: {1: 0, 2: 12, 3: 88, 4: 4, 5: 0, 6: 94, 7: 104, 8: 84, 9: 246, 10: 8, 11: 562, 12: 568, 13: 648, 14: 656, 15: 796, 16: 144, 17: 8, 18: 0, 19: 566, 20: 10, 21: 50, 22: 0, 23: 456, 24: 50, 25: 38, 26: 606, 27: 44, 28: 70, 29: 54, 30: 544, 31: 410, 32: 182, 33: 40, 34: 620, 35: 346, 36: 468, 37: 584, 38: 0, 39: 0, 40: 298, 41: 172, 42: 176, 43: 228, 44: 78, 45: 56, 46: 0, 47: 92, 48: 20, 49: 0, 50: 0}
# Caminho Médio: 11.1
# Diâmetro: 31

# %% [markdown]
# 10. BHW10.bat

# %%
from grafo import ler_arquivo, desenhar_grafo, estatisticas_grafo

grafo = ler_arquivo("selected_instances/BHW10.dat")

estatisticas = estatisticas_grafo(grafo)

print("Estatísticas do grafo:")
for chave, valor in estatisticas.items():
    print(f"{chave}: {valor}")

desenhar_grafo(grafo)
# Out:
# Estatísticas do grafo:
# Qtd Vértices: 77
# Qtd Arestas: 0
# Qtd Arcos: 196
# Qtd Vértices Requeridos: 53
# Qtd Arestas Requeridas: 0
# Qtd Arcos Requeridos: 102
# Densidade: 0.03349282296650718
# Grau Mínimo: 2
# Grau Máximo: 8
# Intermediação: {1: 0, 2: 298, 3: 0, 4: 594, 5: 362, 6: 0, 7: 328, 8: 402, 9: 524, 10: 642, 11: 1210, 12: 786, 13: 80, 14: 32, 15: 270, 16: 126, 17: 0, 18: 934, 19: 1046, 20: 620, 21: 1426, 22: 1316, 23: 606, 24: 572, 25: 466, 26: 346, 27: 0, 28: 30, 29: 0, 30: 0, 31: 562, 32: 474, 33: 194, 34: 0, 35: 202, 36: 0, 37: 262, 38: 0, 39: 376, 40: 454, 41: 816, 42: 1142, 43: 718, 44: 1524, 45: 0, 46: 1362, 47: 1762, 48: 322, 49: 1700, 50: 738, 51: 1052, 52: 218, 53: 102, 54: 0, 55: 0, 56: 412, 57: 176, 58: 1178, 59: 1350, 60: 944, 61: 0, 62: 722, 63: 298, 64: 0, 65: 0, 66: 150, 67: 344, 68: 0, 69: 550, 70: 0, 71: 150, 72: 576, 73: 150, 74: 0, 75: 576, 76: 750, 77: 170}
# Caminho Médio: 181.936
# Diâmetro: 446
